# %%
import pandas as pd

# Load the fraud.csv file into a Pandas DataFrame
df = pd.read_csv("Fraud.csv")

# %%
df0 = df[:5000]
df1 = df.copy()
df2 = df.copy()

# %%
len(df)
# Out:
# 6362620

# %%
df0["step"] = pd.to_timedelta(df0["step"], unit='h')
df0.head()
# Out:
#              step      type    amount     nameOrig  oldbalanceOrg  \
# 0 0 days 01:00:00   PAYMENT   9839.64  C1231006815       170136.0
# 1 0 days 01:00:00   PAYMENT   1864.28  C1666544295        21249.0
# 2 0 days 01:00:00  TRANSFER    181.00  C1305486145          181.0
# 3 0 days 01:00:00  CASH_OUT    181.00   C840083671          181.0
# 4 0 days 01:00:00   PAYMENT  11668.14  C2048537720        41554.0
#
#    newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0       160296.36  M1979787155             0.0             0.0        0
# 1        19384.72  M2044282225             0.0             0.0        0
# 2            0.00   C553264065             0.0             0.0        1
# 3            0.00    C38997010         21182.0             0.0        1
# 4        29885.86  M1230701703             0.0             0.0        0
#
#    isFlaggedFraud
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df0 = df0.dropna()

# %%
df_encoded = pd.get_dummies(df0, columns=['nameOrig'])

# %%
df_encoded
# Out:
#                 step      type     amount  oldbalanceOrg  newbalanceOrig  \
# 0    0 days 01:00:00   PAYMENT    9839.64      170136.00       160296.36
# 1    0 days 01:00:00   PAYMENT    1864.28       21249.00        19384.72
# 2    0 days 01:00:00  TRANSFER     181.00         181.00            0.00
# 3    0 days 01:00:00  CASH_OUT     181.00         181.00            0.00
# 4    0 days 01:00:00   PAYMENT   11668.14       41554.00        29885.86
# ...              ...       ...        ...            ...             ...
# 4995 0 days 05:00:00   CASH_IN   67017.13     3942544.19      4009561.32
# 4996 0 days 05:00:00   CASH_IN  122744.28     4009561.32      4132305.60
# 4997 0 days 05:00:00   CASH_IN  414729.24     4132305.60      4547034.84
# 4998 0 days 05:00:00   CASH_IN  328776.10     4547034.84      4875810.94
# 4999 0 days 05:00:00   CASH_IN   50535.87     4875810.94      4926346.82
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...
